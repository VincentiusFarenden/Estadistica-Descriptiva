# %%
import pandas as pd

df_NOTAS = pd.read_excel('BBDD (Notas P1).xlsx')
df_NOTAS
# Out:
#     Alumno  P1-A  P1-B
# 0        1   5.5   6.9
# 1        2   4.2   2.9
# 2        3   2.8   4.7
# 3        4   6.6   5.4
# 4        5   4.3   6.3
# 5        6   5.6   4.6
# 6        7   3.7   6.4
# 7        8   6.2   6.3
# 8        9   6.8   4.0
# 9       10   6.2   6.1
# 10      11   5.2   5.1
# 11      12   4.6   6.9
# 12      13   2.1   3.8
# 13      14   5.1   2.6
# 14      15   2.5   6.7
# 15      16   4.4   2.5
# 16      17   6.6   2.0
# 17      18   5.3   1.8
# 18      19   4.7   3.7
# 19      20   4.1   5.0
# 20      21   3.8   6.2
# 21      22   6.2   4.4
# 22      23   2.7   2.7
# 23      24   1.6   2.6
# 24      25   NaN   6.6
# 25      26   NaN   1.0
# 26      27   NaN   5.9
# 27      28   NaN   5.1
# 28      29   NaN   1.2
# 29      30   NaN   3.6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Promedio_A = round(df_NOTAS['P1-A'].mean(),1)
Promedio_B = round(df_NOTAS['P1-B'].mean(),1)

Desviacion_A = round(df_NOTAS['P1-A'].std(),1)
Desviacion_B = round(df_NOTAS['P1-B'].std(),1)

CV_A = round((Desviacion_A/Promedio_A)*100,0)
CV_B = round((Desviacion_B/Promedio_B)*100,0)

print("El curso A tiene un promedio de", Promedio_A, ", una desviación estandar de", Desviacion_A, "y un CV de", CV_A, "%")
print("El curso B tiene un promedio de", Promedio_B, ", una desviación estandar de", Desviacion_B, "y un CV de", CV_B, "%")
# Out:
# El curso A tiene un promedio de 4.6 , una desviación estandar de 1.5 y un CV de 33.0 %
# El curso B tiene un promedio de 4.4 , una desviación estandar de 1.8 y un CV de 41.0 %
